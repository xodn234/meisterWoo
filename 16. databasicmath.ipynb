# %% [markdown]
# # 4.1 함수

# %% [markdown]
# # 표를 사용한 함수 구현

# %%
f = {
    1:2,
    2:4,
    3:6,
    4:8,
    5:10
}

# %%
f[1]
# Out:
# 2

# %% [markdown]
# # 변수

# %%
# 함수 정의
def f(x):
    return 2 * x
# 함수 사용
x = 10
y = f(x)

print("f({}) = {}".format(x, y))
# Out:
# f(10) = 20

# %% [markdown]
# # 연속과 불연속

# %% [markdown]
# # 부호함수
# - 양수면 1 음수면 -1 0이면 0출력

# %%
np.sign(11), np.sign(0), np.sign(-11)
# Out:
# (1, 0, -1)

# %% [markdown]
# # 단위계단함수
# - 0포함 양수면 1, 음수는 0출력 [구현필요시 직접 구현해야함]

# %% [markdown]
# # 지시함수
# - 특정 지정한 값이 들어오면 1, 그외 나머지는 0이 출력

# %% [markdown]
# # 역함수
# - 역수와 혼동 X
# - 값이 여려개 나오면 역함수가 존재하지 않는다.

# %% [markdown]
# # 함수의 그래프

# %%
x = np.linspace(-1, 3, 9)
x
# Out:
# array([-1. , -0.5,  0. ,  0.5,  1. ,  1.5,  2. ,  2.5,  3. ])

# %%
y = f(x)
y
# Out:
# array([-2., -1.,  0.,  1.,  2.,  3.,  4.,  5.,  6.])

# %% [markdown]
# # 역함수의 그래프
# - 대칭으로 생김

# %% [markdown]
# # 데이터에서 많이사용하는 함수들
# - 다항식함수
# - 최대함수와 최소함수
# - 지수함수
# - 로지스틱함수
# - 로그함수
# - 소프트플러스함수
# - 다변수함수
# - 분리가능다변수함수
# - 다변수다출력함수
# - 함수의 스케일링

# %%
np.exp(2.3025851), np.log(10)
# Out:
# (10.000000070059542, 2.302585092994046)

# %% [markdown]
# # 심파이를 사용한 함수 미분

# %% [markdown]
# # 기울기

# %% [markdown]
# # 수치미분

# %%
from scipy.misc import derivative

print(derivative(f, 0, dx=1e-6))
print(derivative(f, 1, dx=1e-6))
# Out:
# 1.000000000001
# -2.000000000002

# %% [markdown]
# # 4.2 미분
# - 미분으로 도함수를 만듬

# %% [markdown]
# # 미분가능

# %% [markdown]
# # 미분공식
# - 기본 미분공식
# - 선형조합법칙
# - 곱셈법칙
# - 연쇄법칙

# %% [markdown]
# # 2차 도함수

# %% [markdown]
# # 편미분

# %% [markdown]
# # 다변수 함수의 연쇄법칙

# %% [markdown]
# # 테일러 전개

# %% [markdown]
# # 심파이

# %%
import sympy 
sympy.init_printing(use_latex='mathjax')

# %% [markdown]
#  # 4.3 적분

# %% [markdown]
# # 부정적분

# %% [markdown]
# # 편미분

# %% [markdown]
# # 다차 도함수와 다중적분

# %% [markdown]
# # 정적분

# %% [markdown]
# # 수치적분

# %% [markdown]
# # 다차원 함수의 단일 정적분
