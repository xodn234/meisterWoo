# %% [markdown]
# # 조건문
# - 특정 조건에 따라서 코드를 실행하고자 할떄 사용
# - if, else, elif

# %%
# 조건부분에 : bool 데이터 타입 이외의 데이터 타입이 오면 bool 형변환 되어 판단

if True:
    print("python")
# Out:
# python

# %%
# int : 0을 제외환 나머지 값은 True
bool(0), bool(1), bool(-1), bool(100)
# Out:
# (False, True, True, True)

# %%
num = 0
if num:
    print("python1")
    
num = 1
if num:
    print("python2")
# Out:
# python2

# %%
number = 7

if number % 2:
    print("홀수")
# Out:
# 홀수

# %%
# float : 0.0을 제외한 나머지 실수는 True
# str : ""을 제외한 나머지 문자열은 True
# list, tuple, dict : [], (), {} 을 제외한 나머지는 True

# %%
# 지갑에 돈이 10000원 이상 있으면 택시를 타고 
# 2000원 이상이 있으면 버스를 탑니다.
# 그렇지 않으면 걸어서 집에 갑니다.

money = 5000

if money >= 10000:
    print("택시를 타고 집에 갑니다.")
elif money >= 2000:
    print("버스를 타고 집에 갑니다.")
else:
    print("걸어서 집에 갑니다.")
# Out:
# 버스를 타고 집에 갑니다.

# %%
# 예제
# 계좌에 10000원이 들어 있습니다.
# 인출 금액을 입력 받습니다.
# 인출 금액이 계좌에 있는 금액보다 크면 인출이 불가능 합니다. 출력
# 인출 금액이 계좌에 있는 금액보다 작으면 "인출 되었습니다." 출력
# 마즈막에 현재 계좌의 잔액을 출력

data = int(input("인출 금액을 입력하세요 : "))
money = 10000

if data <= money:
    money -= data
    print(str(data) + "원이 인출되었습니다.")
else:
    print("인출이 불가능 합니다. " + str(data - money) + "원이 부족합니다.")
print("현재잔액은 : " + str(money) + "원 입니다.")
# Out:
# 인출 금액을 입력하세요 : 8000
# 8000원이 인출되었습니다.
# 현재잔액은 : 2000원 입니다.

# %%
# string 데이터 타입의 format 함수
print("{} 인출이 되어 현재 잔액은 {} 입니다.".format(data ,money))
# Out:
# 8000 인출이 되어 현재 잔액은 2000 입니다.

# %%
# 삼항연산자
- 간단한 if, else 구문을 한줄의 코드로 표현할수 있는 방법
- (True) if (condition) else (False)

# %%
# data 변수에 0이면 "zero"를 출력, 아니면 "not zero" 출력
data = 0 
if data:
    print("not zero")
else:
    print("zero")
# Out:
# zero

# %%
data = 0
result = "not zero" if data else "zero"
result
# Out:
# 'zero'

# %%
### 반복문
- 반복되는 코드를 실행할때 사용
- while, for, break, continue
- list comprehention

# %%
# while

data = 3 # 조건이 False가 될때까지 굼누의 코드를 실행
while data:
    print(data)
    data -= 1
# Out:
# 3
# 2
# 1

# %%
# 예제
# 학생이 국어80, 영어90, 수학100점 입니다. while문을 이용하여 총점과 평균을 출력
# 학생의 점수는 list, dict 표현

subject = ["korean", "english", "math"]
point = [80, 90, 100]

total, avg = 0, 0

points = point.copy()

while points:
    total += points.pop()
avg = total / len(point)

total, avg
# Out:
# (270, 90.0)

# %%
# 무한루프
# break : 반복문을 중단 시킬떄 사용되는 예약어

result = 1
while result:
    if result >= 10:
        break
    result += 1
    
print(result)
# Out:
# 10

# %%
# for 
- iterable한 값을 하나씩 꺼내서 value에 대입시킨후 코드를 interable 변수의 값 갯수 만큼
  실행
    
for <variable> in <interables>:
    <code>

# %%
# for - continue : 조건부분으로 올라가서 코드가 실행
ls = [0, 1, 2, 3, 4]
for data in ls: # data가 홀수가 되면 continue를 실행
    if data % 2:
        continue #data가 짝수이면 print를 실행
    print(data, end = " ")
# Out:
# 0 2 4

# %%
# for를 이용하여 100번 실행
# range 함수

list(range(100))
result = 0
for data in range(100):
    result += data
result
# Out:
# 4950

# %%
# offset index 개념과 비슷하게 사용
list(range(3, 10, 2))
# Out:
# [3, 5, 7, 9]

# %%
# 0에서 10까지 짞수를 더한 총합

result = 0
for number in range(0, 11, 2):
    result += number
result
# Out:
# 30

# %%
# dict 이용한 for문

point = {"korean":80, "english":90, "math":100}

list(point.keys())
# Out:
# ['korean', 'english', 'math']

# %%
list(point.items())
# Out:
# [('korean', 80), ('english', 90), ('math', 100)]

# %%
for subject, points in list(point.items()):
    print(subject, points)
# Out:
# korean 80
# english 90
# math 100

# %%
subject = ["korean", "english", "math"]
point = [80, 90, 100]

for sub, po in zip(subject, point):
    print(sub, po)
# Out:
# korean 80
# english 90
# math 100

# %%
# 구구단 출력 (가로 출력)

for num2 in range(1, 10):
    for num1 in range(1, 10):
        print("{}X{}={}".format(num1, num2, num1 * num2), end = "\t")
    print()
# Out:
# 1X1=1	2X1=2	3X1=3	4X1=4	5X1=5	6X1=6	7X1=7	8X1=8	9X1=9
# 1X2=2	2X2=4	3X2=6	4X2=8	5X2=10	6X2=12	7X2=14	8X2=16	9X2=18
# 1X3=3	2X3=6	3X3=9	4X3=12	5X3=15	6X3=18	7X3=21	8X3=24	9X3=27
# 1X4=4	2X4=8	3X4=12	4X4=16	5X4=20	6X4=24	7X4=28	8X4=32	9X4=36
# 1X5=5	2X5=10	3X5=15	4X5=20	5X5=25	6X5=30	7X5=35	8X5=40	9X5=45
# 1X6=6	2X6=12	3X6=18	4X6=24	5X6=30	6X6=36	7X6=42	8X6=48	9X6=54
# 1X7=7	2X7=14	3X7=21	4X7=28	5X7=35	6X7=42	7X7=49	8X7=56	9X7=63
# 1X8=8	2X8=16	3X8=24	4X8=32	5X8=40	6X8=48	7X8=56	8X8=64	9X8=72
# 1X9=9	2X9=18	3X9=27	4X9=36	5X9=45	6X9=54	7X9=63	8X9=72	9X9=81

# %%
## list compretension
- 리스트 데이터를 만들어주는 방법
- for문 보다 빠르게 동작합니다.

# %%
#각각 값에 제곱한 결과 출력
ls = [0, 1, 2, 3]
result=[]
for data in ls:
    result.append(data**2)
result
# Out:
# [0, 1, 4, 9]

# %%
result = [data**2 for data in ls]
result
# Out:
# [0, 1, 4, 9]

# %%
# 리스트 커프리핸션을 써서 홀수와 짝수를 리스트로 출력해주는 코드
ls = [0, 1, 2, 3]
#result = ["짝수", "홀수". "짝수", "홀수"]

result = [
   "홀수" if data %2 else "짝수"
    for data in ls
]
result
# Out:
# ['짝수', '홀수', '짝수', '홀수']

# %%
# 리스트 컴프리샌션 조건문

ls = range(10)
[data for data in ls if data % 2]
# Out:
# [1, 3, 5, 7, 9]

# %%
ls = [1, 2, 3]
[func for func in dir(ls) if func[:2] != "__" and func[0] == "c"]
# Out:
# ['clear', 'copy', 'count']

# %%
# for문과 list comprehention 성능비교

ls = []
for num in range(1,10001):
    if num % 2 == 0:
        ls.append(num)
len(ls)
# Out:
# 5000

# %%
ls = [num for num in range(1, 10001) if num % 2 == 0]
len(ls)
# Out:
# 5000

# %% [markdown]
# ### 함수
# - 반복되는 코드를 묶음으로 효율적인 코드를 작성하도록 해주는 기능
# - 기본 함수
# - 파라미터와 아규먼트
# - 리턴
# - '*args', '**kwargs'
# - docstring
# - scope
# - inner function
# - lambda function
# - Map, Filter, reduce
# - Decorlator

# %%
# 기본함수
- 선언과 호출

# %%
point = 88

if point >= 90:
    print("A")
elif point >= 80:
    print("B")
else:
    print("c")
# Out:
# B

# %%
# 함수 선언

def grade(point):
    if point >= 90:
        print("A")
    elif point >= 80:
        print("B")
    else:
        print("c")

# %%
# 함수 호출

grade(88)
# Out:
# B

# %%
### 파라미터와 아규먼트
- 파라미터 : 함수를 선언할때 호출하는 부분에서 보내주는 데이터를 받는 변수
- 아규먼트 : 함수를 호출할때 함수에 보내주는 데이터

# %%
def plus(num1, num2=20, num3=10): #파라미터 : 디폴트 파라미터
   print(num1 + num2 - num3)

# %%
plus(1, 2) #아규먼트 : 키워드 아규먼트
# Out:
# -7

# %%
plus(1, num3=100)
# Out:
# -79

# %%
print(1, 2, end ="=")
print(3)
# Out:
# 1 2=3

# %%
# 리턴
- 함수를 실행한 결과를 저장하고 싶을떄 사용
- return

# %%
def plus(num1, num2):
    print(num1 + num2)
    return num1 + num2

# %%
result = plus(1, 2)
print(result)
# Out:
# 3
# 3

# %%
data1 = "python"
result = data1.upper()
print(result)
# Out:
# PYTHON

# %%
data2 = [3, 1, 2]
result = data2.sort()
print(result)
# Out:
# None

# %%
point = 88
result = grade(point)
print(result)
# Out:
# B
# None

# %%
# 함수에서 return 코드가 실행되면 무조건 함수의 코드 실행이 종료
def echo(msg):
    if msg == "quit":
        return
    print(msg)

# %%
echo("python")
# Out:
# python

# %%
echo("quit")

# %%
# args, kwargs
- 함수를 호출할때 아규먼트와 키워드 아규먼트의 갯수를 특정지을수 없을때 사용

# %%
def plus(*args, **kwargs):
    print(type(args), args)
    print(type(kwargs), kwargs)
    return sum(args) + sum(kwargs.values())

# %%
plus(1, 2, 3, num1=6, num2=7)
# Out:
# <class 'tuple'> (1, 2, 3)
# <class 'dict'> {'num1': 6, 'num2': 7}
# 19

# %%
def func(num1, num2, num3=20):
    return num1 + num2 + num3

data = [1, 2, 3]
func(*data) # func(1, 2, 3)
#func(data) # func([1, 2, 3])
# Out:
# 6

# %%
data = {
    "num2":100,
    "num3":200
}
func(1, **data) #func(1, num2=100, num3=200)
# Out:
# 301

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? n
# Nothing done.

# %% [markdown]
# % %reset error
#
# - ipython 버전을 downgrade
#     - conda uninstall ipython
#     - conda install ipython=7.2.0
#     - conda install jupyter

# %% [markdown]
# ### 복습1
# - 조건문
#     - if, else, elif
#     - 특정 조건에 따라서 코드를 실행하고 싶을떄 사용
# - 반복문
#     - while, for
#     - 특정 코드를 반복적으로 실행 시키고 싶을때 사용
#     - continue, break

# %%
# 문장을 입력받아서 문법에 맞도록 결과를 출력하는 코드를 작성
# 마지막 문자는 . 이 있을수도 있고없을수도 있습니다. 
# python IS the best Language
# ptthon is the best language

# 1. 문자열 입력 받기
sentence = input("input sentence : ")

# 2. 모두 수문자로 변경
result = sentence.lower()

#3. 가장 앞글자를 대문자로 변경
result = result[0].upper() + result[1:]

#4. 마즈막 문자가 .인지 확인해서 .이 아니면 .을 추가
if result[-1] != ".":
    result += "."

result
# Out:
# input sentence : python is the best language
# 'Python is the best language.'

# %%
# 6자리의 로또번호를 생성하는 코드를 작성하세요.
# 6자리의 번호는 중복이 x
import random

#lotto = random.randint(1, 45)

lotto = []

while True:
    
    number = random.randint(1, 45)
    
    if number not in lotto:
        lotto.append(number)
    
    if len(lotto) >= 6:
        lotto.sort()
        break
        
lotto
# Out:
# [2, 4, 5, 7, 22, 35]

# %%
- 함수
    - 중복되는 코드를 묶어서 효율적으로 코드를 작성하기 위해 사용
    - 기본함수 : 선언(def), 호출(func_name())
    - argument, parameter, keyword arg, defult, parameter
    - return
    - *args, **kwargs

# %%
- 함수 2
    - docstring (shift tap)
    - scope
    - inner function
    - lambda function
    - map, filter, reduce
    - decorlator

# %%
## docstring 
# 함수의 설명을 작성

def echo(mag):
    "echo print msg"
    print(mag)

# %%
def echo(mag):
    """
    wcho func return its input agument
    the operation is:
        1. print mag
        2. return mag parameter
    param : mag : str
    return : str
    
    """
    return mag

# %%
# 1. 쉬프트 탭   2. ?붙이기  3. ??붙이기 4. help(echo) 4.echo__doc__
echo??

# %%
### Scope 범위
- 함수 안에서 선언되는 변수와 함수 밖에서 선언되는 변수의 범위가 다릅니다. 
- global(전역), local(지역)

# %%
# global

gv = 10

def echo():
    print(gv)
    
echo()
gv
# Out:
# 10
# 10

# %%
# local

gv = 10

def echo():
    gv = 100
    print(gv)
    
echo()
gv
# Out:
# 100
# 10

# %%
gv = 10

def echo():
    global gv
    gv = 100
    print(gv)
    
echo()
gv
# Out:
# 100
# 100

# %%
# inner function
- 함수가 지역영역에 선언, 함수 안에 함수가 선언

# %%
def outer(a, b):
    
    def inner(c, d):
        return c + d
    
    return inner(a, b)

# %%
outer(1, 2)
# Out:
# 3

# %%
inner(3, 4) # 지역함수는 전역영역에서 사용이 불가
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-277-7566bf9bccf6> in <module>
# ----> 1 inner(3, 4)
#
# NameError: name 'inner' is not defined

# %%
def outer(a, b):
    
    def inner(c, d):
        print(a, b)
        return c + d
    
    return inner

# %%
outer(1, 2)(3, 4) #inner(3, 4)
# Out:
# 1 2
# 7

# %%
# callback function : 함수를 아규먼트 파라미터로 설정해서 사용

# %%
def calc(func, a, b):
    a **= 2
    b **= 2
    return func(a, b)

# %%
def plus(a, b):
    return a + b

# %%
def minus (a, b):
    return a - b

# %%
calc(plus, 1, 2)
# Out:
# 5

# %%
calc(minus, 1, 2)
# Out:
# -3

# %%
# 람다함수
- 파라미터를 간단한 계산으로 리턴되는 함수 : 삼항연산

# %%
plus1 = lambda a, b:a + b

# %%
plus1(1, 2)
# Out:
# 3

# %%
# calc(func, a, b)
calc(lambda a, b: a * b, 3, 4)
# Out:
# 144

# %%
# map, filter, reduce
- map : 순서가 있는 데이터 집합에서 모든 값에 함수를 적용시킨 결과

# %%
ls = [1, 2, 3, 4]

def odd_even(num):
    return "odd" if num % 2 else "even"

odd_even(3), odd_even(4)
# Out:
# ('odd', 'even')

# %%
list(map(odd_even, ls))
# Out:
# ['odd', 'even', 'odd', 'even']

# %%
# input 함수로 구분자는 ""으로 여러개의 숫자를 입력 받습니다.
# str.split(" ")리스트로 만들고
#만들어진 리스트의 값들을 int 형변환

# %%
datas = input("insert numbers :")
# Out:
# insert numbers :10 20 30 40 10

# %%
result = datas.split(" ")
result
# Out:
# ['10', '20', '30', '40', '10']

# %%
result = list(map(int, result))
result
# Out:
# [10, 20, 30, 40, 10]

# %%
# 멀티수정 옵션 드래그
1112234
2112234

# %%
## Filter
- 리스트 데이터에서 특정 조건에 맞는 value만 남기는 함수

# %%
ls = range(10)

# %%
# 홀수만 출력
list(filter(lambda data: True if data % 2 else False, ls))
# Out:
# [1, 3, 5, 7, 9]

# %%
#ls = [1, 2, 3]
#*ls - (1, 2, 3)

# %%
# Reduce
- 리스트 데이터를 처음부터 순서대로 특정 함수를 실행하여 결과를 누적시켜 주는 함수

# %%
from functools import reduce

# %%
ls = [3, 1, 2, 4, 5]
reduce(lambda x, y: x + y, ls)
# Out:
# 15

# %%
# Decorlator
- 함수에서 코드를 바꾸지 않고 기능을 추가하거나 수정하고 싶을때 사용하는 문법

'''
def a():
    code_1
    code_2
    code_3
    
def b():
    code_1
    code_4
    code_3
'''

위와 같은 코드를 데코레이터로 사용하는법

'''
def c(func):
    
    def wrapper(*args, **kwargs):
        code_1
        result = func(*args, **kwargs)
        code_3
        result result
        
    return wrapper
    
@c
def a():
    code_2
    
@c
def b():
    code_4
'''

# %%
# a
def plus(a, b):
    print("start")                      # code1
    result = a + b                      # code2
    print("result : {}".format(result)) # code3
    return result

# %%
# b
def minus(a, b):
    print("start")                      # code1
    result = a - b                      # code4
    print("result : {}".format(result)) # code3
    return result

# %%
# c
def disp(func):
    def wrapper(*args, **kwargs):
        print("start")                      # code1
        result = func(*args, **kwargs)      # code2, code4
        print("result : {}".format(result)) # code3
        return result
    return wrapper

# %%
@disp
def plus(a, b):                    
    result = a + b      #code 2                
    return result

# %%
plus(1, 3)
# Out:
# start
# result : 4
# 4

# %%
# 함수의 실행 시간을 출력하는 데코레이터 함수를 작성하세요.

import time

def timer(func):
    def wrapper(*args, **kwargs):
        start_time = time.time()
        result = func(*args, **kwargs)
        end_time = time.time()
        print("running time : {}".format(end_time - start_time))
        return result
    return wrapper

# %%
#@timer
def test1(num1, num2):
    data = range(num1, num2+1)
    return sum(data)

# %%
@timer
def test2(num1, num2):
    result = 0
    for num in range(num1, num2+1):
        result += num
    return result

# %%
test1(1, 10000)
# Out:
# 50005000

# %%
test2(1, 10000)
# Out:
# running time : 0.0007066726684570312
# 50005000

# %%
# 패스워드를 입력 받아야 함수가 실행되도록하는 데코레이터 작성

def check_password(func):
    def wrapper(*args, **kwargs):
        
        pw = "dss11"
        
        input_pw = input("insert pw : ")
        
        if input_pw == pw:
            result = func(*args, **kwargs)
        else:
            result = "not allow"
        
        return result
    return wrapper

# %%
@check_password
def plus(a, b):
    return a + b

# %%
plus(1, 2)
# Out:
# insert pw : dss11
# 3

# %%
import random

@check_password
def lotto_func():
    lotto = []
    while True:
        number = random.randint(1, 45)
        if number not in lotto:
            lotto.append(number)
        if len(lotto) >= 6:
            lotto.sort()
            break
    return lotto

# %%
lotto_func()
# Out:
# insert pw : dss11
# [2, 3, 10, 19, 28, 44]
