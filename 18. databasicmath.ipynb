# %% [markdown]
# # 확률분포의 분산

# %% [markdown]
# # 분산의 성질
#
# - 분산은 항상 0 또는 양수이다
# - 확률변수가 아닌 상수 값 c에 대해 다음 식이 성립한다.

# %% [markdown]
# # 두 확률변수의 합의 분산
#
# - 마즈막 항은 양수도 될 수 있고 음수도 될 수 있다.

# %% [markdown]
# # 확률변수의 독립
#
# - 두확률변수가 서로 독립 이라는 것은 두 확률변수가 가질 수 있는 모든 사건의 조합에 대해 결합사건의 확률이
#   각 사건의 확률의 곱과 같다는 뜻이다.
# - 독립의 반대, 즉 두 확률변수에서 하나의 확률변수의 값이 특정한 값이면 다른 확률변수의 확률뷴포가 영향을 받아
#   변하게 되면 종속 이라고 한다.

# %% [markdown]
# # 표본평균의 분산
#
# - 표본평균을 계산한 표본 개수가 커지면 표본평균의 값의 변동은 작아진다. 표본의 수가 무한대가 되면 표분평균의
#   값은 항상 일정한 겂이 나온다. 즉 확률적인 값이 아니라 결정론적인 값이 된다.

# %% [markdown]
# # 표분분산의 기댓값
#
# - 표분분산의 기대값을 구하면 이론적인 분산과 같아지는 것이아니라 이론적인 분산값의 N-1/N 배가 된다.
#   즉 표본분산값이 이론적인 분산값보다 더 작아진다.

# %% [markdown]
# # 비대칭도와 첨도

# %% [markdown]
# # 모멘트
#
# - 모멘트는 확률분포에서 계산한 특징값이다.

# %% [markdown]
# # 7.4 다변수 확률 변수

# %% [markdown]
# # 결합확률질량함수

# %% [markdown]
# # 주변확률질량함수
#
# - 두 확률변수 중 하나의 확률변수 값에 대해서만 확률분포를 표시한 함수이다. 즉 다변수가 되기 이전의 단변수 확률질량함수를
#   말한다.

# %% [markdown]
# # 조건부확률질량함수

# %% [markdown]
# # 주변확률 밀도함수

# %% [markdown]
# # 독립과 상관
#
# - 두 확률변수가 있을때 한 확률변수의 표본 값이 달라지면 다른 확률변수의 조건부 분포가 달라질 떄 서로 상관 관계가 있다고한다. 반대로 두 확률변수가 상관 관계가 아니면 서로 독립니라고 한다.

# %% [markdown]
# # 반복시행
#
# - 확률변수에서 복수의 표본 데이터를 취하는 경우에는 이 표본들은 서로 독립인 확률변수들에서 나온 표본으로 볼 수 있다.

# %% [markdown]
# # 조건부 확률 분포
#
# - 확률변수 X가 다른 확률변서 Y에 독립이면 조건부 확률 분포가 조건이 되는 확률변수에 값에 영향을 받지않는다.

# %% [markdown]
# # 독립 확률변수의 기댓값

# %% [markdown]
# # 독립확률변수의 분산

# %% [markdown]
# # 7.5 공분산과 상관계수

# %% [markdown]
# # 표본 공분산

# %% [markdown]
# # 표본 상관계수
#
# - 표분공분산은 평균을 중심으로 각 자료들이 어떻게 분포되어 있는지 크기와 방향성을 같이 보여준다.
#   그런데 분포의 크기는 공분산이 아닌 분산만으로도 알 수 있기 때문에 대두분의 경우 자료 분포의 방향성만 불리하여
#   보는 것이 유용하다. 이 떄 필요한 것이 표본상관계수다.

# %% [markdown]
# # 확률변수의 공분산과 상관계수
#
# - p = 1 : 완전선형 상관관계
# - p = 0 : 무상관 (독립과는 다름)
# - p = -1 : 완전선형 반상관관계

# %% [markdown]
# # 비선형 상관관계

# %% [markdown]
# # 엔스콤 데이터

# %% [markdown]
# # 다변수 확률변수 표본공분산

# %% [markdown]
# # 7.6 조건부기댓값과 예측문제

# %% [markdown]
# # 조건부기댓값의 성질

# %% [markdown]
# # 전체 기댓값의 법칙

# %% [markdown]
# # 조건부분산

# %% [markdown]
# # 사이파이를 이용한 확률분포

# %%
import scipy as sp
import scipy.stats

# %% [markdown]
# # 모수
#
# - 확률분포 객체를 생성할 떄는 분포의 형상을 구체적으로 지정하는 모수를 인수로 주어야 한다.

# %% [markdown]
# # 무작위 표본 생성
#
# - 무작위 표본을 만들때는 rvs메서드를 사용한다.

# %% [markdown]
# # 8.2 베르누이분포와 이항분포

# %% [markdown]
# # 베르누이 시행
#
# - 결과가 두가지 중 하나로만 나오는 실험이나 시행을 베르누이 시행이라고 한다.

# %% [markdown]
# # 베르누이 확률변수
#
# - 베르누이 시행의 결과를 실수 0 또는 1로 바꾼것을 베르누이 확률변수하 한다.

# %% [markdown]
# # 베르누이 확률분포
#
# - 베르누이 확률변수의 분포를 베르누이 확률분포 혹은 베르누이 분포라고 한다.
# - 베르누이분포는 1이 나올확률을 의미하눈 u(뮤)라는 모수를 가진다.

# %% [markdown]
# # 베르누이분포의 모멘트

# %% [markdown]
# # 이항분포
#
# - 성공할확률이 u인 베르누이 시행을 N번 반복하는 경우를 생각해보면 가장 운이좋을때에는 N번 모두 성공할 것이고
#   가장 운이 나쁜 경우에는 한번도 성공하지 못할 것이다. N번중 성공한 횟수를 확률변서 X라고 한다면
#   X의 값은 0부터 N까지의 정수 중 하나가 될것이다. 이런 확률변수를 이항분포를 따르는 확률변수라고 한다.

# %% [markdown]
# # 이항분포의 모멘트

# %% [markdown]
# # 베르누의분포와 이항분포의 모수측정
#
# - 데이터에서 모수의 값을 찾아내는 것을 모수추정이라고 한다.

# %% [markdown]
# # 베르누이분포의 활용
#
# - 분류예측 문제의 출력 데이터가 두 값으로 구분되는 카테고리값인 경우에 분류결과 즉, 두 값중 어는 값이 가능성이
#   높은지를 표현하는데 사용된다.(베이지안 관점)
# - 입력 데이터가 0 또는 1 혹은 참 또는 거짓, 두 개의 값으로 구분되는 카테고리값은 경우, 두 종류의 값이 나타나는
#   비율을 표현하는데 사용된다.(빈도주의적 관점)

# %% [markdown]
# # 8.3 카테고리분포와 다항분포

# %% [markdown]
# # 카테고리 확률변수
#
# - 베르누이 확률변수는 0이나 1이 나오는 확률변수였다. 동전이 아닌 주사위를 던져서 나오는 경우는 어떻게 표현 하는가?
#   카테고리 확률변수는 1부터 k까지 k개 정숫값중 하나가 나온다. 이 정숫값을 카테고리 혹은 클래스라고 한다.

# %% [markdown]
# # 카테고리 확률분포

# %% [markdown]
# # 다중 분류문제
#
# - 스팸메일 필러링과 같은 이진분류문제에서는 베르누이분포를 사용했다. 예측할범주값이 두가지보다 많은 다중분류문제 에서는
#   카테고리분포를 사용하여 범주값 데이터 모형을 만들 수 있다.

# %% [markdown]
# # 다항분포
#
# - 베르누이 확률변수의 데이터가 복수이면 이 데이터의 합이 이항분포를 이루는 것처럼 카테고리 확률변수의 데이터가
#   여럿 있으면 이 데이터의 합은 다항분포가 된다.

# %% [markdown]
# # 다항분포의 모멘트

# %% [markdown]
# # 정규분포와 중심극한정리
#
# - 정규분포 혹은 가우스 정규분호라는 분포는 자연현상에서 나타나는 숫자를 확률모형으로 모형화할 떄 많이 사용한다.
# - 정규분포 중에서도 평균이 0이고 분산이 1인 정규분포를 표준정규뷴포라 한다.

# %% [markdown]
# # 로그정규분포
#
# - 주가의 수익률이 정규본포라면 주가 자체는 로그정규뷴포가 된다.

# %% [markdown]
# # Q-Q 플롯
#
# - Q-Q플롯은 분석할 표본 데이터의 분포와 정규뷴포의 분포 형태를 비교하여 표본 데이터가 정규분포를 따르는지 검사하는 간단한
#   시각적 도구이다.

# %% [markdown]
# # 중심극한 정리
#
# - 실세계에서 발생하는 현상 중 많은 것들이 정규분포로 모형화 가능하다. 그 이유 중의 하나는 중심극한정리다.

# %% [markdown]
# # 정규분포의 통계량 분포

# %% [markdown]
# # 선형회귀모형과 정규분포
#
# - 정규분포는 선형회귀모형에서 잡음을 모형화하는데 사용된다.

# %% [markdown]
# # 8.5 스튜던트 t분포, 카이제곱분포, F분포

# %% [markdown]
# # 스튜던트 t분포
#
# - 펫 테일을 보이는 데이터 모형에 적합한 것이 스튜던트 t분포이다.

# %% [markdown]
# # t통계량
#
# - 정규본포로부터 얻은 N개의 표본에서 계산한 표본평균을 표본표준편차로 정규화한 값을 t통계량이라고 한다.

# %% [markdown]
# # 카이제곱 분포
#
# - N개의 표본들을 단순히 더하는 것이 아니라 제곱을 하여 더하면 양수값만을 가지는 분포가 된다
#   이 분포를 카이제곱분포라 한다.

# %% [markdown]
# # F분포
#
# - 스튜던트 t분포의 표본값을 제곱한 값은 F분포를 따른다.

# %% [markdown]
# # 다변수정규분포
#
# - D다차원 다변수정규분포의 확률밀도함수는 평균벡터와 공분산행렬 이라는 두개의 모수를 가진다.

# %% [markdown]
# # 다변수정규뷴포와 고윳값 분해
#
# - 다변수정규뷴포의 공분산 행렬은 양의 정부호인 대칭행렬이므로 대각화가능이다.

# %% [markdown]
# # 다변수정규분포의 조건부 확률분포
#
# - 다변수정규분포인 확률변수벡터 중 어떤 원소의 값이 주어지면다른 확률변수의 조건부확률분포는 다변수 정규분포이다.

# %% [markdown]
# # 다변수 정규분포의 주변확률분포
#
# - 다변수정규뷴포의 주변확률뷴포는 다변수정규분포다.
